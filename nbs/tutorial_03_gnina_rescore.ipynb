# %% [markdown]
# # Gnina rescore with docked ligand

# %% [markdown]
# ## Setup

# %%
from kdock.core import Data
from kdock.gnina_rescore import *
import pandas as pd, numpy as np

# %% [markdown]
# ## Rescore

# %% [markdown]
# Get folder that contains the AF3 .cif files

# %%
df = get_gnina_rescore_folder('~/mirati_structure')

# %%
df.ID = df.ID.str[:-15]

# %% [markdown]
# ## Merge with target

# %%
target = Data.get_mirati_g12d()

# %%
target.ID=target.ID.str.lower()

# %%
target['log_Kd'] = np.log(target['Kd'] + 1e-5)
target['log_IC50'] = np.log(target['IC50'] + 1e-5)
target['log_erk_IC50'] = np.log(target['erk_IC50'] + 1e-5)

# %%
out =target.merge(df)

# %%
target
# Out:
#            ID                                             SMILES       Kd  \
# 0        us_1  CN1CCC[C@H]1COc1nc(N2CC3CCC(C2)N3)c2cnc(cc2n1)...     97.7
# 1        us_4  Oc1cc(-c2ncc3c(nc(OCCc4ccccn4)nc3c2F)N2CC3CCC(...    155.7
# 2        us_5  Cn1nccc1COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-...    294.8
# 3        us_6  Cc1cccnc1CCOc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1...    442.2
# 4        us_7  Oc1cc(-c2ncc3c(nc(OCCc4ncccn4)nc3c2F)N2CC3CCC(...    463.5
# ..        ...                                                ...      ...
# 655  paper_23  FC1=C(C2=C(C=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OCC...      NaN
# 656  paper_22  FC1=C(C2=C(C=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OCC...      NaN
# 657  paper_35  FC1=C(C2=C(C(F)=C(F)C=C3)C3=CC=C2)N=CC4=C1N=C(...      NaN
# 658     us_56  OC[C@@H](O)COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n...  13805.3
# 659     us_66  Fc1c(ncc2c(nc(OC[C@@]34CCCN3C(CCl)CC4)nc12)N1C...      NaN
#
#        IC50  erk_IC50
# 0     124.7    3159.1
# 1     496.2    8530.0
# 2     722.9    8193.8
# 3     434.1   11518.2
# 4    1867.3       NaN
# ..      ...       ...
# 655   750.5   10000.0
# 656    12.0     650.0
# 657     7.0      97.0
# 658  6024.0       NaN
# 659   273.8    1332.6
#
# [660 rows x 5 columns]

# %%
# out.to_csv('ssss.csv',index=False)

# %% [markdown]
# ## Correlation

# %%
out.corr(numeric_only=True)
# Out:
#                       Kd      IC50  erk_IC50    log_Kd  log_IC50  \
# Kd              1.000000  0.137290 -0.088274  0.567310  0.081667
# IC50            0.137290  1.000000  0.379993  0.409676  0.405385
# erk_IC50       -0.088274  0.379993  1.000000  0.340125  0.712639
# log_Kd          0.567310  0.409676  0.340125  1.000000  0.685839
# log_IC50        0.081667  0.405385  0.712639  0.685839  1.000000
# log_erk_IC50   -0.167722  0.242495  0.734366  0.489439  0.782773
# binding_energy  0.057419  0.053732  0.021735  0.248538  0.122679
# uncertainty    -0.018275  0.043736  0.180512 -0.040339  0.226303
# RMSD           -0.024215  0.004029 -0.053734  0.127363  0.032245
# CNNscore       -0.013420 -0.022743 -0.035309 -0.250781 -0.132452
# CNNaffinity    -0.074127 -0.113720 -0.087744 -0.268039 -0.224498
# CNNvariance    -0.006572 -0.013407  0.108684  0.116238  0.141299
#
#                 log_erk_IC50  binding_energy  uncertainty      RMSD  CNNscore  \
# Kd                 -0.167722        0.057419    -0.018275 -0.024215 -0.013420
# IC50                0.242495        0.053732     0.043736  0.004029 -0.022743
# erk_IC50            0.734366        0.021735     0.180512 -0.053734 -0.035309
# log_Kd              0.489439        0.248538    -0.040339  0.127363 -0.250781
# log_IC50            0.782773        0.122679     0.226303  0.032245 -0.132452
# log_erk_IC50        1.000000        0.104519     0.182658 -0.024072 -0.106300
# binding_energy      0.104519        1.000000    -0.446689  0.585530 -0.693636
# uncertainty         0.182658       -0.446689     1.000000 -0.341865  0.440134
# RMSD               -0.024072        0.585530    -0.341865  1.000000 -0.532004
# CNNscore           -0.106300       -0.693636     0.440134 -0.532004  1.000000
# CNNaffinity        -0.181381       -0.759297     0.352636 -0.522074  0.714560
# CNNvariance         0.160417        0.548717    -0.149078  0.296449 -0.317445
#
#                 CNNaffinity  CNNvariance
# Kd                -0.074127    -0.006572
# IC50              -0.113720    -0.013407
# erk_IC50          -0.087744     0.108684
# log_Kd            -0.268039     0.116238
# log_IC50          -0.224498     0.141299
# log_erk_IC50      -0.181381     0.160417
# binding_energy    -0.759297     0.548717
# uncertainty        0.352636    -0.149078
# RMSD              -0.522074     0.296449
# CNNscore           0.714560    -0.317445
# CNNaffinity        1.000000    -0.195504
# CNNvariance       -0.195504     1.000000

# %%
out.corr('spearman',numeric_only=True)
# Out:
#                       Kd      IC50  erk_IC50  binding_energy  uncertainty  \
# Kd              1.000000  0.770684  0.484753        0.307595    -0.041586
# IC50            0.770684  1.000000  0.821105        0.214860     0.201848
# erk_IC50        0.484753  0.821105  1.000000        0.150561     0.201548
# binding_energy  0.307595  0.214860  0.150561        1.000000    -0.317127
# uncertainty    -0.041586  0.201848  0.201548       -0.317127     1.000000
# RMSD            0.198397  0.019858 -0.023826        0.642633    -0.290202
# CNNscore       -0.318074 -0.164505 -0.118687       -0.723730     0.329470
# CNNaffinity    -0.343751 -0.355147 -0.287123       -0.723106     0.111949
# CNNvariance     0.173958  0.205119  0.202999        0.457403    -0.021203
#
#                     RMSD  CNNscore  CNNaffinity  CNNvariance
# Kd              0.198397 -0.318074    -0.343751     0.173958
# IC50            0.019858 -0.164505    -0.355147     0.205119
# erk_IC50       -0.023826 -0.118687    -0.287123     0.202999
# binding_energy  0.642633 -0.723730    -0.723106     0.457403
# uncertainty    -0.290202  0.329470     0.111949    -0.021203
# RMSD            1.000000 -0.664650    -0.442909     0.441766
# CNNscore       -0.664650  1.000000     0.635484    -0.412043
# CNNaffinity    -0.442909  0.635484     1.000000    -0.269412
# CNNvariance     0.441766 -0.412043    -0.269412     1.000000
